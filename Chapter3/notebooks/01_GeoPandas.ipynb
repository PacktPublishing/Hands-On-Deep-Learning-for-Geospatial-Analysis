# %% [markdown]
# # Introduction to GeoPandas

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file("../data/admin_0/ne_10m_admin_0_countries.shp", encoding="utf-8")

# %%
gdf.head()
# Out:
#         featurecla  scalerank  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 0  Admin-0 country          5          2  Indonesia    IDN         0      2
# 1  Admin-0 country          5          3   Malaysia    MYS         0      2
# 2  Admin-0 country          6          2      Chile    CHL         0      2
# 3  Admin-0 country          0          3    Bolivia    BOL         0      2
# 4  Admin-0 country          0          2       Peru    PER         0      2
#
#                 TYPE      ADMIN ADM0_A3  \
# 0  Sovereign country  Indonesia     IDN
# 1  Sovereign country   Malaysia     MYS
# 2  Sovereign country      Chile     CHL
# 3  Sovereign country    Bolivia     BOL
# 4  Sovereign country       Peru     PER
#
#                          ...                          NAME_KO    NAME_NL  \
# 0                        ...                            인도네시아  Indonesië
# 1                        ...                            말레이시아   Maleisië
# ...

# %%
gdf.columns
# Out:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'ADMIN', 'ADM0_A3', 'GEOU_DIF', 'GEOUNIT',
#        'GU_A3', 'SU_DIF', 'SUBUNIT', 'SU_A3', 'BRK_DIFF', 'NAME', 'NAME_LONG',
#        'BRK_A3', 'BRK_NAME', 'BRK_GROUP', 'ABBREV', 'POSTAL', 'FORMAL_EN',
#        'FORMAL_FR', 'NAME_CIAWF', 'NOTE_ADM0', 'NOTE_BRK', 'NAME_SORT',
#        'NAME_ALT', 'MAPCOLOR7', 'MAPCOLOR8', 'MAPCOLOR9', 'MAPCOLOR13',
#        'POP_EST', 'POP_RANK', 'GDP_MD_EST', 'POP_YEAR', 'LASTCENSUS',
#        'GDP_YEAR', 'ECONOMY', 'INCOME_GRP', 'WIKIPEDIA', 'FIPS_10_', 'ISO_A2',
#        'ISO_A3', 'ISO_A3_EH', 'ISO_N3', 'UN_A3', 'WB_A2', 'WB_A3', 'WOE_ID',
#        'WOE_ID_EH', 'WOE_NOTE', 'ADM0_A3_IS', 'ADM0_A3_US', 'ADM0_A3_UN',
#        'ADM0_A3_WB', 'CONTINENT', 'REGION_UN', 'SUBREGION', 'REGION_WB',
#        'NAME_LEN', 'LONG_LEN', 'ABBREV_LEN', 'TINY', 'HOMEPART', 'MIN_ZOOM',
# ...

# %%
gdf2 = gdf[['NAME', 'POP_EST', 'CONTINENT', 'geometry']]
gdf2.head()
# Out:
#         NAME    POP_EST      CONTINENT  \
# 0  Indonesia  260580739           Asia
# 1   Malaysia   31381992           Asia
# 2      Chile   17789267  South America
# 3    Bolivia   11138234  South America
# 4       Peru   31036656  South America
#
#                                             geometry
# 0  (POLYGON ((117.7036079039552 4.163414542001791...
# 1  (POLYGON ((117.7036079039552 4.163414542001791...
# 2  (POLYGON ((-69.51008875199994 -17.506588197999...
# 3  POLYGON ((-69.51008875199994 -17.5065881979999...
# 4  (POLYGON ((-69.51008875199994 -17.506588197999...

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

f, ax = plt.subplots(1, figsize=(25,12.5), dpi=300)
gdf2.plot(ax=ax)
#plt.savefig("world.png")
